# %%
# Anastasiia Kolomytseva
# Python for Data Analysts: Methods & Tools - DAT-7466 - BMBANDD1
# A2: Game Theory - The Python Equilibrium


# import random package

import random


# ask if the user wants to play the game

valid_answers = ["yes", "no"]
game = input('Hello! Do you want to play a game today? (yes/no) ').lower()

# loop in case the user does invalid input (it returns the user to the question)

while game not in valid_answers:
    print("I am sorry, I did not catch. Please enter 'yes' or 'no'.")
    game = input("Do you want to play a game today? (yes/no)")

# if the user wants to play

if 'yes' in game:
    
    user = input('''
Perfect! Lets play a game then! You will play against Python! 
One more question. What is your name? ''').capitalize()
    
    print(f'\n Nice to meet you {user}! You have been assigned to do an assignment with your classmate and it is very hard!')
    print('''
 Well, the professor expects a lot from you, so you need to work as a team. 
 Otherwise, you can get an F!
    ''')
    
# the game instructions
    
    print(f''' 
    Here are some outputs that you and your teammate can have. {user}, everything depends on you! 
    Choose what you will do wisely!
    
    \n
    {user} \ Teammate  \t\tCollaborate   \t\t\t\tDoes not collaborate
    _________________________________________________________________________________________________________
   | Collaborate        | You both get a B       | {user} does all the work and gets an A, because professor      |
   |                    |                        | feels bad for the student, while Teammate gets an F       |
   |_________________________________________________________________________________________________________|
   | Do not collaborate | Teammate does          | You both get an F                                         |
   |                    | everything             |                                                           |
   |                    | and gets an A,         |                                                           |
   |                    | while {user} gets an F      |                                                           |
   |_________________________________________________________________________________________________________|
   
   ''')
    

    # create a game with the pay-off matrix
    
    game = [[0, 5],[1, 4]]
    
    # save results in a dictionary
    
    dictionary = {'(C,C)': (game[1][1], game[1][1]),
                '(D,C)': (game[1][0], game[0][1]),
                '(C,D)': (game[0][1], game[1][0]),
                '(D,D)': (game[0][0], game[0][0])}
    
    # user choose what to do
    
    valid_answers_2 = ["C", "D"]
    
    user_choice = input('''
    So, what will you do? Will you be a good teammate and collaborate or will not collaborate at all?
    
    Your options:
    C - Collaborate
    D - Do not collaborate
    ''').upper()
    
    # loop in case the user does invalid input (it returns the user to the question)
    
    while user_choice not in valid_answers_2:
        print('Seems like you made something wrong. Try again! Please enter C or D')
        user_choice = input('''
    So, what will you do? Will you be a good teammate and collaborate or will not collaborate at all?
    
    Your options:
    C - Collaborate
    D - Do not collaborate
    ''').upper()
        
    # if loop that proceeds the program to the scenario outputs
    
    if user_choice == 'C' or user_choice == 'D':
        print('Good choice! Hm... but what did your teammate pick?')
    
    # random answer of the computer: 1 - Collaborate, 0 - Do not collaborate
    
        computer_choice = random.randint(0,1)
    
    # outputs for each scenario
    
        if user_choice == 'C' and computer_choice == 1:  # scenario in which both players collaborate
            user_r = dictionary ['(C,C)'] [0]
            computer_r = dictionary ['(C,C)'] [1]
            print(f'''
        Hey! We decided to collaborate and do the assignment together! Cool!
        
        You got {user_r} point(s)
        I got {computer_r} point(s)''')
        
        elif user_choice == 'D' and computer_choice == 1:  # scenario in which user decides not to collaborate, while computer collaborates
            user_r = dictionary ['(D,C)'] [0]
            computer_r = dictionary ['(D,C)'] [1]
            print(f'''
        You are the worst teammate I had! I did all the work alone! :(
        
        You got {user_r} point(s)
        I got {computer_r} point(s)''')
        
        elif user_choice == 'C' and computer_choice == 0:  # scenario in which computer decides not to collaborate, while user collaborates
            user_r = dictionary ['(C,D)'] [0]
            computer_r = dictionary ['(C,D)'] [1]
            print(f'''
       I'm sorry I was busy doing some personal things :( At least you got a higher grade!
        
        You got {user_r} point(s)
        I got {computer_r} point(s)''')
        
        elif user_choice == 'D' and computer_choice == 0:  # scenario in which both players do not collaborate
            user_r = dictionary ['(D,D)'] [0]
            computer_r = dictionary ['(D,D)'] [1]
            print(f'''
        Unfortunately both of us got a bad grade, because we did not do anything :(
        
        You got {user_r} point(s)
        I got {computer_r} point(s)
        ''')
            
 # loops for final results' comparison 
    
    if user_r > computer_r:
        print(f"""Congrats to {user}, you won!""")

    elif user_r == computer_r:
        print(f"""There is a tie!""")

    elif user_r < computer_r:
        print(f"""Well, {user}, you lost!""")
        
        
# if the user does not want to play

elif 'no' in game:
    
    print('''
Ok! See you next time! I will play with another Python player then :c But you can watch!
    ''')
    
# the instructions that Python players follow
    
    print(f'\n We have been assigned to do the assignment and it is very hard!')
    
    print('''
 Well, the professor expects a lot from us, so we need to work as a team. 
 Otherwise, we can get an F!
    ''')
    
    print(f''' 
    Here are some outputs that Player 1 and Player 2 can have. 
    
    \n
    Player 1 \ Player 2 \tCollaborate   \t\t\t\tDoes not collaborate
     __________________________________________________________________________________________________________
   | Collaborate        | We both get a B       | Player 2 does all the work and gets an A, because professor  |
   |                    |                       | feels bad for the student, while Player 1 gets an F          |
   |____________________________________________ ______________________________________________________________|
   | Do not collaborate | Player 1 does         | You both get an F                                            |
   |                    | everything            |                                                              |
   |                    | and gets an A,        |                                                              |
   |                    | while Player 2        |                                                              |
   |                    | gets an F             |                                                              |
   |___________________________________________________________________________________________________________|
   
    ''')
    
    print('''
    Let's see what we will get!
    ''')

     
    # create a game with the pay-off matrix
    
    game = [[0, 5],[1, 4]]
    
    # save results in a dictionary
    
    dictionary = {'(C,C)': (game[1][1], game[1][1]),
                '(D,C)': (game[1][0], game[0][1]),
                '(C,D)': (game[0][1], game[1][0]),
                '(D,D)': (game[0][0], game[0][0])} 

    
    # randomize previous choices 
    
    previous_choice = random.randint(0,1)
    
     # set the value of the final variables
    
    player_1_total = 0
    player_2_total = 0
    
    # for loop to run the 5 rounds of the game
    
    for round_n in range(1,6):
        
        print(f'''
        Round # {round_n}
        ''')
        computer_choice = random.randint(0,1)
        
        if previous_choice is None:
            computer_choice_2 = 1
            
        else:
            computer_choice_2 = previous_choice
            previous_choice = computer_choice
      
    # outputs for each possible scenario     
        
        if computer_choice_2 == 1 and computer_choice == 1 :  # scenario in which both players collaborate
            computer_choice_2_r = dictionary ['(C,C)'] [0]
            computer_r = dictionary ['(C,C)'] [1]
            print(f'''
        Hey! We decided to collaborate and do the assignment together! Cool!
        
        Player 1 got {computer_r} point(s)
        Player 2 got {computer_choice_2_r} point(s)''')
    
        elif computer_choice_2 == 0 and computer_choice == 1 :  # scenario in which player 2 does not collaborate, and player 1 does
            computer_choice_2_r = dictionary ['(D,C)'] [0]
            computer_r = dictionary ['(D,C)'] [1]
            print(f'''
        Player 2 is the worst teammate Player 1 had! Player 1 did all the work! :(
        
        Player 1 got {computer_r} point(s)
        Player 2 got {computer_choice_2_r} point(s)''')
        
        elif computer_choice_2 == 1 and computer_choice == 0 :  # scenario in which player 1 does not collaborate, and player 2 does
            computer_choice_2_r = dictionary ['(C,D)'] [0]
            computer_r = dictionary ['(C,D)'] [1]
            print(f'''
       Player 1 was busy and let Player 2 down! :( At least Player 2 got a higher grade!
        
        Player 1 got {computer_r} point(s)
        Player 2 got {computer_choice_2_r} point(s)''')
        
        elif computer_choice_2 == 0 and computer_choice == 0 :  # scenario in which both players do not collaborate
            computer_choice_2_r = dictionary ['(D,D)'] [0]
            computer_r = dictionary ['(D,D)'] [1]
            print(f'''
        Unfortunately both Players got a bad grade, because they did not do anything :(
        
        Player 1 got {computer_r} point(s)
        Player 2 got {computer_choice_2_r} point(s)
        ''')

    # creation of final variables
    
        player_1_total += computer_r
        player_2_total += computer_choice_2_r
        
        print('  __________________________________________________________________________________________')

    # total points for each Pyhton player
    
    print(f'''
    **Player 1's** total points: {player_1_total}
    **Player 2's** total points: {player_2_total}''')
    
    print('  _______________________________________')
    
    print('''
    Let's see who won! The winner is...
    ''')
    
    # loops for final results' comparison 
    
    if player_2_total > player_1_total:
        print(f"""Congrats to Player 2! Player 2 won""")

    elif player_2_total == player_1_total:
        print(f"""There is a tie!""")

    elif player_2_total < player_1_total:
        print(f"""Congrats to Player 1, it beat Player 2!""")
# Out:
# Hello! Do you want to play a game today? (yes/no) yes
#
# Perfect! Lets play a game then! You will play against Python!
# One more question. What is your name? l
#
#  Nice to meet you L! You have been assigned to do an assignment with your classmate and it is very hard!
#
#  Well, the professor expects a lot from you, so you need to work as a team.
#  Otherwise, you can get an F!
#
#
#     Here are some outputs that you and your teammate can have. L, everything depends on you!
#     Choose what you will do wisely!
#
#
#
#     L \ Teammate  		Collaborate   				Does not collaborate
#     _________________________________________________________________________________________________________
#    | Collaborate        | You both get a B       | L does all the work and gets an A, because professor      |
#    |                    |                        | feels bad for the student, while Teammate gets an F       |
# ...
